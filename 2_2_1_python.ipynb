# %% [markdown]
# # Data Manipulation and Summary Statistics with pandas
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/RMS_Titanic_3.jpg/1920px-RMS_Titanic_3.jpg)
#
# ![](./img/Pandas_Cheat_Sheet.jpg)

# %%
import pandas as pd

# %%
#Load Data
PATH = "./data/titanic.csv"

df = pd.read_csv(PATH)

#Show the the count of rows and columns
df.shape
# Out:
# (891, 15)

# %% [markdown]
# #### Top 5 Rows
# [Reference](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html#pandas-dataframe-head)

# %%
df.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #### Bottom 5 Rows
# [Reference](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.tail.html#pandas-dataframe-tail)

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# #### Columns

# %%
# Select a single columns
# Note: you can also use the dot operator "but it is not the default"
# df.
df["survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
# List of columns to select
col_ls = ["sex", "fare", "survived"]

# Subset the columns
df[col_ls]
# Out:
#         sex     fare  survived
# 0      male   7.2500         0
# 1    female  71.2833         1
# 2    female   7.9250         1
# 3    female  53.1000         1
# 4      male   8.0500         0
# ..      ...      ...       ...
# 886    male  13.0000         0
# 887  female  30.0000         1
# 888  female  23.4500         0
# 889    male  30.0000         1
# 890    male   7.7500         0
#
# [891 rows x 3 columns]

# %%
# Create a new column and set values to one
df["new_column"] = 1
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  new_column
# 0    man        True  NaN  Southampton    no  False           1
# 1  woman       False    C    Cherbourg   yes  False           1
# 2  woman       False  NaN  Southampton   yes   True           1
# 3  woman       False    C  Southampton   yes  False           1
# 4    man        True  NaN  Southampton    no   True           1

# %%
# Create a new column from other columns
df["new_column2"] = df["class"] + " " + df["embark_town"]
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  new_column  \
# 0    man        True  NaN  Southampton    no  False           1
# 1  woman       False    C    Cherbourg   yes  False           1
# 2  woman       False  NaN  Southampton   yes   True           1
# 3  woman       False    C  Southampton   yes  False           1
# 4    man        True  NaN  Southampton    no   True           1
#
#          new_column2
# 0  Third Southampton
# 1    First Cherbourg
# 2  Third Southampton
# 3  First Southampton
# 4  Third Southampton

# %%
# Renaming the column names

df.rename(columns= {'new_column': 'something'})
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  something  \
# 0      man        True  NaN  Southampton    no  False          1
# 1    woman       False    C    Cherbourg   yes  False          1
# 2    woman       False  NaN  Southampton   yes   True          1
# 3    woman       False    C  Southampton   yes  False          1
# 4      man        True  NaN  Southampton    no   True          1
# ..     ...         ...  ...          ...   ...    ...        ...
# 886    man        True  NaN  Southampton    no   True          1
# 887  woman       False    B  Southampton   yes   True          1
# 888  woman       False  NaN  Southampton    no  False          1
# 889    man        True    C    Cherbourg   yes   True          1
# 890    man        True  NaN   Queenstown    no   True          1
#
#             new_column2
# 0     Third Southampton
# 1       First Cherbourg
# 2     Third Southampton
# 3     First Southampton
# 4     Third Southampton
# ..                  ...
# 886  Second Southampton
# 887   First Southampton
# 888   Third Southampton
# 889     First Cherbourg
# 890    Third Queenstown
#
# [891 rows x 17 columns]

# %%
# Renaming more than one column names
# add them in a dictionary 
# key --> old title
# value --> new title

df.rename(columns= {'new_column': 'something', 'new_column2': 'something2' })
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  something  \
# 0      man        True  NaN  Southampton    no  False          1
# 1    woman       False    C    Cherbourg   yes  False          1
# 2    woman       False  NaN  Southampton   yes   True          1
# 3    woman       False    C  Southampton   yes  False          1
# 4      man        True  NaN  Southampton    no   True          1
# ..     ...         ...  ...          ...   ...    ...        ...
# 886    man        True  NaN  Southampton    no   True          1
# 887  woman       False    B  Southampton   yes   True          1
# 888  woman       False  NaN  Southampton    no  False          1
# 889    man        True    C    Cherbourg   yes   True          1
# 890    man        True  NaN   Queenstown    no   True          1
#
#              something2
# 0     Third Southampton
# 1       First Cherbourg
# 2     Third Southampton
# 3     First Southampton
# 4     Third Southampton
# ..                  ...
# 886  Second Southampton
# 887   First Southampton
# 888   Third Southampton
# 889     First Cherbourg
# 890    Third Queenstown
#
# [891 rows x 17 columns]

# %%
# Note: Another way to renaming more than one column 

edit_names = {'new_column': 'something', 'new_column2': 'something2'}

df.rename(columns= edit_names)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  something  \
# 0      man        True  NaN  Southampton    no  False          1
# 1    woman       False    C    Cherbourg   yes  False          1
# 2    woman       False  NaN  Southampton   yes   True          1
# 3    woman       False    C  Southampton   yes  False          1
# 4      man        True  NaN  Southampton    no   True          1
# ..     ...         ...  ...          ...   ...    ...        ...
# 886    man        True  NaN  Southampton    no   True          1
# 887  woman       False    B  Southampton   yes   True          1
# 888  woman       False  NaN  Southampton    no  False          1
# 889    man        True    C    Cherbourg   yes   True          1
# 890    man        True  NaN   Queenstown    no   True          1
#
#              something2
# 0     Third Southampton
# 1       First Cherbourg
# 2     Third Southampton
# 3     First Southampton
# 4     Third Southampton
# ..                  ...
# 886  Second Southampton
# 887   First Southampton
# 888   Third Southampton
# 889     First Cherbourg
# 890    Third Queenstown
#
# [891 rows x 17 columns]

# %% [markdown]
# #### Slicing
#
# - [loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)
#     - Label based slicing ---> use the name of the column for selection
# - [iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html)
#     - Index based slicing ---> use the index of the column for selection

# %%
# Grab first 5 rows
df[0:5]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  new_column  \
# 0    man        True  NaN  Southampton    no  False           1
# 1  woman       False    C    Cherbourg   yes  False           1
# 2  woman       False  NaN  Southampton   yes   True           1
# 3  woman       False    C  Southampton   yes  False           1
# 4    man        True  NaN  Southampton    no   True           1
#
#          new_column2
# 0  Third Southampton
# 1    First Cherbourg
# 2  Third Southampton
# 3  First Southampton
# 4  Third Southampton

# %%
# Look at bottom five rows
df[-5:]
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  new_column  \
# 886    man        True  NaN  Southampton    no   True           1
# 887  woman       False    B  Southampton   yes   True           1
# 888  woman       False  NaN  Southampton    no  False           1
# 889    man        True    C    Cherbourg   yes   True           1
# 890    man        True  NaN   Queenstown    no   True           1
#
#             new_column2
# 886  Second Southampton
# 887   First Southampton
# 888   Third Southampton
# 889     First Cherbourg
# 890    Third Queenstown

# %%
# Use index based slicing to grab first 5 rows and first 5 columns
df.iloc[0:5,0:5]
# Out:
#    survived  pclass     sex   age  sibsp
# 0         0       3    male  22.0      1
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1
# 4         0       3    male  35.0      0

# %%
# Use index based slicing to grab last 5 rows and last 5 columns
df.iloc[-5:,-5:]
# Out:
#      embark_town alive  alone  new_column         new_column2
# 886  Southampton    no   True           1  Second Southampton
# 887  Southampton   yes   True           1   First Southampton
# 888  Southampton    no  False           1   Third Southampton
# 889    Cherbourg   yes   True           1     First Cherbourg
# 890   Queenstown    no   True           1    Third Queenstown

# %%
# Use label based slicing to grab first 5 rows and first 5 columns "from survived until sibsp"
df.loc[0:5,"survived":"sibsp"]
# Out:
#    survived  pclass     sex   age  sibsp
# 0         0       3    male  22.0      1
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1
# 4         0       3    male  35.0      0
# 5         0       3    male   NaN      0

# %%
# Use label based slicing to grab "a range of columns" the last 5 rows and last 5 columns
df.loc[-5:,"adult_male":"alone"]
# Out:
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 5 columns]

# %%
# Use label based slicing to grab all the rows and specific columns 
# Note: the columns are arranged based on your listing NOT based on the order in the dataset

df.loc[:,["adult_male","alone", "survived"]]
# Out:
#      adult_male  alone  survived
# 0          True  False         0
# 1         False  False         1
# 2         False   True         1
# 3         False  False         1
# 4          True   True         0
# ..          ...    ...       ...
# 886        True   True         0
# 887       False   True         1
# 888       False  False         0
# 889        True   True         1
# 890        True   True         0
#
# [891 rows x 3 columns]

# %% [markdown]
# ## Sampling from the dataset
#
# ## you can sample data by:
#
# * specific number of rows
# * specific fraction of rows

# %%
df.shape
# Out:
# (891, 17)

# %%
# Note: Used to get a specific number of data points

df.sample(n = 100)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 137         0       1    male  37.0      1      0   53.1000        S   First
# 278         0       3    male   7.0      4      1   29.1250        Q   Third
# 830         1       3  female  15.0      1      0   14.4542        C   Third
# 695         0       2    male  52.0      0      0   13.5000        S  Second
# 815         0       1    male   NaN      0      0    0.0000        S   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 177         0       1  female  50.0      0      0   28.7125        C   First
# 261         1       3    male   3.0      4      2   31.3875        S   Third
# 872         0       1    male  33.0      0      0    5.0000        S   First
# 390         1       1    male  36.0      1      2  120.0000        S   First
# 133         1       2  female  29.0      1      0   26.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone  new_column  \
# 137    man        True    C  Southampton    no  False           1
# 278  child       False  NaN   Queenstown    no  False           1
# 830  child       False  NaN    Cherbourg   yes  False           1
# 695    man        True  NaN  Southampton    no   True           1
# 815    man        True    B  Southampton    no   True           1
# ..     ...         ...  ...          ...   ...    ...         ...
# 177  woman       False    C    Cherbourg    no   True           1
# 261  child       False  NaN  Southampton   yes  False           1
# 872    man        True    B  Southampton    no   True           1
# 390    man        True    B  Southampton   yes  False           1
# 133  woman       False  NaN  Southampton   yes  False           1
#
#             new_column2
# 137   First Southampton
# 278    Third Queenstown
# 830     Third Cherbourg
# 695  Second Southampton
# 815   First Southampton
# ..                  ...
# 177     First Cherbourg
# 261   Third Southampton
# 872   First Southampton
# 390   First Southampton
# 133  Second Southampton
#
# [100 rows x 17 columns]

# %%
# Note: Used to get a specific portion/percentage of data points

df.sample(frac = 0.3)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 435         1       1  female  14.0      1      2  120.0000        S  First
# 577         1       1  female  39.0      1      0   55.9000        S  First
# 147         0       3  female   9.0      2      2   34.3750        S  Third
# 676         0       3    male  24.5      0      0    8.0500        S  Third
# 860         0       3    male  41.0      2      0   14.1083        S  Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 823         1       3  female  27.0      0      1   12.4750        S  Third
# 455         1       3    male  29.0      0      0    7.8958        C  Third
# 297         0       1  female   2.0      1      2  151.5500        S  First
# 380         1       1  female  42.0      0      0  227.5250        C  First
# 227         0       3    male  20.5      0      0    7.2500        S  Third
#
#        who  adult_male deck  embark_town alive  alone  new_column  \
# 435  child       False    B  Southampton   yes  False           1
# 577  woman       False    E  Southampton   yes  False           1
# 147  child       False  NaN  Southampton    no  False           1
# 676    man        True  NaN  Southampton    no   True           1
# 860    man        True  NaN  Southampton    no  False           1
# ..     ...         ...  ...          ...   ...    ...         ...
# 823  woman       False    E  Southampton   yes  False           1
# 455    man        True  NaN    Cherbourg   yes   True           1
# 297  child       False    C  Southampton    no  False           1
# 380  woman       False  NaN    Cherbourg   yes   True           1
# 227    man        True  NaN  Southampton    no   True           1
#
#            new_column2
# 435  First Southampton
# 577  First Southampton
# 147  Third Southampton
# 676  Third Southampton
# 860  Third Southampton
# ..                 ...
# 823  Third Southampton
# 455    Third Cherbourg
# 297  First Southampton
# 380    First Cherbourg
# 227  Third Southampton
#
# [267 rows x 17 columns]

# %% [markdown]
# #### Filtering DataFrames
#
# To Filter DataFrames based on codintional statement we will pass the condition into the DataFrame using the following syntax.
#
# ```python
# my_condition = condition
# df[my_condition]
# ```

# %%
# Filter DataFrame for rows of Males only (1 condition)

condition = df["sex"] == "male"

df[condition]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  new_column  \
# 0      man        True  NaN  Southampton    no  False           1
# 4      man        True  NaN  Southampton    no   True           1
# 5      man        True  NaN   Queenstown    no   True           1
# 6      man        True    E  Southampton    no   True           1
# 7    child       False  NaN  Southampton    no  False           1
# ..     ...         ...  ...          ...   ...    ...         ...
# 883    man        True  NaN  Southampton    no   True           1
# 884    man        True  NaN  Southampton    no   True           1
# 886    man        True  NaN  Southampton    no   True           1
# 889    man        True    C    Cherbourg   yes   True           1
# 890    man        True  NaN   Queenstown    no   True           1
#
#             new_column2
# 0     Third Southampton
# 4     Third Southampton
# 5      Third Queenstown
# 6     First Southampton
# 7     Third Southampton
# ..                  ...
# 883  Second Southampton
# 884   Third Southampton
# 886  Second Southampton
# 889     First Cherbourg
# 890    Third Queenstown
#
# [577 rows x 17 columns]

# %%
# Filter DataFrame for rows of Males and Survived only (2 conditions)
condition2 = (df["sex"] == "male") & (df["survived"] == 1)
df[condition2]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 17          1       2  male   NaN      0      0  13.0000        S  Second
# 21          1       2  male  34.0      0      0  13.0000        S  Second
# 23          1       1  male  28.0      0      0  35.5000        S   First
# 36          1       3  male   NaN      0      0   7.2292        C   Third
# 55          1       1  male   NaN      0      0  35.5000        S   First
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 838         1       3  male  32.0      0      0  56.4958        S   Third
# 839         1       1  male   NaN      0      0  29.7000        C   First
# 857         1       1  male  51.0      0      0  26.5500        S   First
# 869         1       3  male   4.0      1      1  11.1333        S   Third
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone  new_column  \
# 17     man        True  NaN  Southampton   yes   True           1
# 21     man        True    D  Southampton   yes   True           1
# 23     man        True    A  Southampton   yes   True           1
# 36     man        True  NaN    Cherbourg   yes   True           1
# 55     man        True    C  Southampton   yes   True           1
# ..     ...         ...  ...          ...   ...    ...         ...
# 838    man        True  NaN  Southampton   yes   True           1
# 839    man        True    C    Cherbourg   yes   True           1
# 857    man        True    E  Southampton   yes   True           1
# 869  child       False  NaN  Southampton   yes  False           1
# 889    man        True    C    Cherbourg   yes   True           1
#
#             new_column2
# 17   Second Southampton
# 21   Second Southampton
# 23    First Southampton
# 36      Third Cherbourg
# 55    First Southampton
# ..                  ...
# 838   Third Southampton
# 839     First Cherbourg
# 857   First Southampton
# 869   Third Southampton
# 889     First Cherbourg
#
# [109 rows x 17 columns]

# %%
# Filter DataFrame for rows of Males and Survived and Fare > 15 only (3 conditions)
# Only look at columns: age, class
condition3 = (df["sex"] == "male") & (df["survived"] == 1) & (df["fare"] > 15)

# apply the conditions --> return all the rows but only 2 columns (age and class)
df[condition3].loc[:, ["age", "class"]]
#df[condition3]
# Out:
#        age   class
# 23   28.00   First
# 55     NaN   First
# 65     NaN   Third
# 74   32.00   Third
# 78    0.83  Second
# ..     ...     ...
# 831   0.83  Second
# 838  32.00   Third
# 839    NaN   First
# 857  51.00   First
# 889  26.00   First
#
# [69 rows x 2 columns]

# %%
# The total number of males who survived 
condition3 = (df["sex"] == "male") & (df["survived"] == 1) 

# Important Note: Why did the sum work in the column and did not work for other columns
df[condition3].loc[:, ["survived"]].sum()
# Out:
# survived    109
# dtype: int64

# %%
# Note: this will give me the sum of all the coulmns (numerical and categorical) that satisfy condition3 

df[condition3].sum()
# Out:
# /var/folders/j9/_fdtn83x1_59xgdy16mvsfh80000gn/T/ipykernel_6447/1942301689.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[condition3].sum()
# survived                                                     109
# pclass                                                       220
# sex            malemalemalemalemalemalemalemalemalemalemalema...
# age                                                      2536.67
# sibsp                                                         42
# parch                                                         39
# fare                                                   4449.5418
# embarked       SSSCSCSSSCSCSSSSSSSCCSSSSSSSSSSSQSSSSCSSSSSSSS...
# class          SecondSecondFirstThirdFirstThirdThirdSecondThi...
# who            manmanmanmanmanmanmanchildmanmanmanchildmanman...
# adult_male                                                    88
# embark_town    SouthamptonSouthamptonSouthamptonCherbourgSout...
# alive          yesyesyesyesyesyesyesyesyesyesyesyesyesyesyesy...
# alone                                                         64
# new_column                                                   109
# new_column2    Second SouthamptonSecond SouthamptonFirst Sout...
# dtype: object

# %%
# The total number of males who did not survive
condition3 = (df["sex"] == "male") & (df["survived"] == 0) 

df[condition3].loc[:, ["survived"]].count()
# Out:
# survived    468
# dtype: int64

# %% [markdown]
# #### Numerical Summary Statistics
# [Reference](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        new_column
# count       891.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0

# %% [markdown]
# #### Categorical Summary Statistics
# [Reference](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)

# %%
df.describe(exclude="number")
# Out:
#          sex embarked  class  who adult_male deck  embark_town alive alone  \
# count    891      889    891  891        891  203          889   891   891
# unique     2        3      3    3          2    7            3     2     2
# top     male        S  Third  man       True    C  Southampton    no  True
# freq     577      644    491  537        537   59          644   549   537
#
#               new_column2
# count                 889
# unique                  9
# top     Third Southampton
# freq                  353

# %% [markdown]
# #### Info about the DataFrame
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage.
#
# [Reference](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  new_column   891 non-null    int64
#  16  new_column2  889 non-null    object
# dtypes: bool(2), float64(2), int64(5), object(8)
# memory usage: 106.3+ KB

# %%
# How many missing values in each column

df.isnull().sum()


# Example on sub-sectioning for more accurate missing values replacement
# replace missing value with mean 
# two condition survived, sex

# 1st subset: survived = 0  sex = female, ---> mean
# 2nd subset: survived = 1  sex = female, ---> mean
# 3rd subset: survived = 0  sex = male, ---> mean
# 4th subset: survived = 1  sex = male, ---> mean
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# new_column       0
# new_column2      2
# dtype: int64

# %% [markdown]
# #### Aggregation Methods
#
# ##### Refrences
# - [Mean](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html)
# - [Median](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html)
# - [Mode](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html)
# - [Value Counts](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
# - [Standard Deviation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.mean.html)
# - [Sum](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html)
# - [Count](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.count.html)

# %%
# Mean
df["fare"].mean()
# Out:
# 32.2042079685746

# %%
# Median
df["fare"].median()
# Out:
# 14.4542

# %%
# Mode 
df["fare"].mode()
# Out:
# 0    8.05
# dtype: float64

# %%
# Value Counts (Value counts shows the counts of each values in your column)
df["class"].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df["survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
# Stanadard Deviation
df["fare"].std()
# Out:
# 49.693428597180905

# %%
# Sum (Add all fares together)
df["fare"].sum()
# Out:
# 28693.9493

# %%
# Count (Count all instances of a fare)
df["fare"].count()
# Out:
# 891
